# %%
# !pwd
# Out:
# /home/cse-lab/Desktop/B192389

# %%
# !ls
# Out:
#  INTROPYTHON.ipynb   MELBOURNE_HOUSE_PRICES_LESS.csv  'xl files.ipynb'

# %%
import pandas as pd

# %%
df=pd.read_csv("MELBOURNE_HOUSE_PRICES_LESS.csv")

# %%
df.head(19)
# Out:
#             Suburb             Address  Rooms Type      Price Method  \
# 0       Abbotsford       49 Lithgow St      3    h  1490000.0      S
# 1       Abbotsford       59A Turner St      3    h  1220000.0      S
# 2       Abbotsford       119B Yarra St      3    h  1420000.0      S
# 3       Aberfeldie          68 Vida St      3    h  1515000.0      S
# 4     Airport West    92 Clydesdale Rd      2    h   670000.0      S
# 5     Airport West        4/32 Earl St      2    t   530000.0      S
# 6     Airport West      3/74 Hawker St      2    u   540000.0      S
# 7     Airport West   1/26 Highridge Cr      3    h   715000.0     SP
# 8        Albanvale       1 Jackson Cct      6    h        NaN     PI
# 9      Albert Park         18 Mills St      3    h  1925000.0      S
# 10          Albion  3/15 Drummartin St      3    u   515000.0      S
# 11          Albion      3A Kororoit St      4    h   717000.0      S
# 12      Alphington        55 Fulham Rd      2    h  1675000.0      S
# ...

# %%
df.tail(4)
# Out:
#                  Suburb         Address  Rooms Type     Price Method SellerG  \
# 63019     Roxburgh Park     9 Parker Ct      3    h  500000.0      S   Raine
# 63020     Roxburgh Park  5 Parkinson Wy      3    h  545000.0      S   Raine
# 63021        Thomastown  3/1 Travers St      3    u       NaN     PI   Barry
# 63022  Williams Landing     1 Diadem Wy      4    h       NaN     SP  Aussie
#
#              Date  Postcode             Regionname  Propertycount  Distance  \
# 63019  31/03/2018      3064  Northern Metropolitan           5833      20.6
# 63020  31/03/2018      3064  Northern Metropolitan           5833      20.6
# 63021  31/03/2018      3074  Northern Metropolitan           7955      15.3
# 63022  31/03/2018      3027   Western Metropolitan           1999      17.6
#
#                    CouncilArea
# 63019        Hume City Council
# 63020        Hume City Council
# 63021  Whittlesea City Council
# 63022     Wyndham City Council

# %%
#for no of rows and columns
print(df.shape)
# Out:
# (63023, 13)

# %%
#drop problmatic rows
df=df.dropna()

# %%
print(df.shape)
# Out:
# (48433, 13)

# %%
rooms=df["Rooms"]

# %%
Price=list(df["Price"])

# %%
import matplotlib.pyplot as plt

# %%
print(min(Price))
print(max(Price))
# Out:
# 85000.0
# 11200000.0

# %%
fig=plt.figure()
plt.hist(x=Price,edgecolor="pink",bins=10)
plt.xlabel("price")
plt.ylabel("no.of houses")
plt.title("HISTOGRAM OF PRICE")
plt.show()

# %%
rooms_count=df["Rooms"].value_counts()

# %%
rooms_count=dict(rooms_count)

# %%
rooms_count
# Out:
# {3: 21812,
#  4: 11576,
#  2: 10674,
#  5: 2350,
#  1: 1670,
#  6: 283,
#  7: 36,
#  8: 19,
#  10: 6,
#  12: 2,
#  9: 2,
#  31: 1,
#  16: 1,
#  11: 1}

# %%
rooms_count=df["Rooms"].value_counts()

# %%
print(rooms_count)
# Out:
# 3     21812
# 4     11576
# 2     10674
# 5      2350
# 1      1670
# 6       283
# 7        36
# 8        19
# 10        6
# 12        2
# 9         2
# 31        1
# 16        1
# 11        1
# Name: Rooms, dtype: int64

# %%
a=rooms_count.keys()
b=rooms_count.values()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-66-3f0205f3ba78> in <module>
#       1 a=rooms_count.keys()
# ----> 2 b=rooms_count.values()
#
# TypeError: 'numpy.ndarray' object is not callable

# %%
region_count=df["Regionname"].value_counts()

# %%
region_count=dict(region_count)

# %%
print(region_count)
# Out:
# {'Northern Metropolitan': 13598, 'Southern Metropolitan': 12549, 'Western Metropolitan': 9680, 'Eastern Metropolitan': 7585, 'South-Eastern Metropolitan': 4010, 'Northern Victoria': 455, 'Eastern Victoria': 374, 'Western Victoria': 182}

# %%
r=region_count.keys()
rc=region_count.values()

# %%
#PIE CHART
fig=plt.figure(figsize=(9,9))
plt.pie(x=rc,labels=r)
plt.legend()
plt.show()

# %%
#bar plot
#type
type_count=df["Type"].value_counts()
type_count=dict(type_count)
print(type_count)
# Out:
# {'h': 34161, 'u': 9292, 't': 4980}

# %%
suburb_count=df["Suburb"].value_counts()
suburb_count=dict(suburb_count)
print(suburb_count)
# Out:
# {'Reservoir': 1067, 'Bentleigh East': 696, 'Richmond': 642, 'Craigieburn': 598, 'Preston': 593, 'Mount Waverley': 556, 'Brunswick': 540, 'Northcote': 496, 'Cheltenham': 493, 'Glen Waverley': 486, 'Essendon': 485, 'Glenroy': 482, 'Coburg': 464, 'Mill Park': 454, 'South Yarra': 436, 'Glen Iris': 434, 'Pascoe Vale': 433, 'Bundoora': 431, 'Kew': 430, 'Hawthorn': 429, 'Epping': 421, 'St Kilda': 410, 'Balwyn North': 407, 'Brighton': 404, 'Thornbury': 394, 'Doncaster East': 393, 'Hoppers Crossing': 381, 'Bentleigh': 378, 'Camberwell': 376, 'Brighton East': 366, 'Port Melbourne': 362, 'Greensborough': 357, 'Yarraville': 351, 'Moonee Ponds': 322, 'Werribee': 319, 'Malvern East': 314, 'Mentone': 313, 'Ascot Vale': 313, 'Mitcham': 308, 'Carnegie': 307, 'Prahran': 307, 'Keilor East': 304, 'Footscray': 304, 'Balwyn': 299, 'Mulgrave': 297, 'Lalor': 297, 'Frankston': 292, 'Newport': 290, 'Brunswick West': 289, 'Hampton': 288, 'Elwood': 282, 'Doncaster': 278, 'Surrey Hills': 277, 'Thomastown': 273, 
# ...

# %%
method_count=df["Method"].value_counts()
method_count=dict(method_count)
print(method_count)
# Out:
# {'S': 30624, 'SP': 6480, 'PI': 5940, 'VB': 5024, 'SA': 365}

# %%
distance_count=df["Distance"].value_counts()
distance_count=dict(distance_count)
print(distance_count)
# Out:
# {10.5: 1171, 13.8: 1099, 12.0: 1067, 8.4: 1047, 6.2: 973, 17.9: 947, 14.7: 933, 5.3: 925, 20.6: 854, 5.2: 829, 16.7: 823, 18.0: 780, 11.2: 756, 15.5: 750, 14.0: 720, 2.4: 709, 6.4: 678, 10.2: 666, 6.7: 658, 10.4: 651, 11.4: 649, 7.5: 629, 4.3: 601, 16.1: 599, 21.5: 595, 7.3: 579, 10.1: 568, 14.2: 556, 6.3: 553, 14.3: 540, 18.4: 533, 13.4: 526, 17.2: 512, 12.4: 510, 3.5: 507, 7.2: 482, 12.1: 480, 5.1: 437, 2.7: 436, 8.5: 433, 5.4: 430, 19.6: 421, 4.6: 419, 11.7: 416, 8.9: 415, 5.0: 410, 9.7: 407, 12.9: 405, 38.0: 399, 7.0: 394, 31.7: 389, 3.6: 382, 7.8: 382, 3.4: 378, 7.7: 376, 10.3: 366, 8.8: 364, 17.3: 361, 15.4: 340, 23.0: 339, 27.0: 335, 7.9: 335, 3.0: 334, 25.9: 334, 20.0: 313, 19.9: 305, 8.2: 301, 12.3: 301, 18.8: 297, 16.3: 297, 6.8: 285, 15.3: 273, 16.0: 264, 14.8: 259, 13.1: 259, 22.2: 257, 20.5: 256, 12.7: 242, 14.5: 242, 4.1: 235, 21.3: 233, 24.7: 224, 1.8: 223, 20.4: 215, 0.0: 207, 5.7: 205, 15.2: 204, 4.0: 197, 1.9: 197, 9.5: 194, 17.5: 192, 16.2: 192, 10.8: 177, 9.4: 171
# ...

# %%
#bar plot
#type
k=list(type_count.keys())
v=list(type_count.values())

# %%
fig=plt.figure(figsize=(9,9))
plt.bar(x=k,height=v,edgecolor="pink")
plt.title("types of houses")
plt.show()

# %%
#pie chart
#type

# %%
property_count=df["Propertycount"].value_counts()

# %%
property_count=dict(property_count)

# %%
a=property_count.keys()
b=property_count.values()

# %%
fig=plt.figure(figsize=(10,10))
plt.pie(x=b,labels=a)
plt.show()

# %%
#scatter plot
price=df["Price"]#no need to count
price=list(price)
distance=df["Distance"]
distance=list(distance)

# %%
#line plot
fig=plt.figure(figsize=(9,9))
plt.title("distance vs price")
plt.xlabel("distance")
plt.ylabel("price")

plt.plot(distance,price,linestyle="-",marker="o",color="black",markerfacecolor="pink")
plt.show()

# %%
rooms=df["Rooms"]
rooms=list(rooms)
distance=df["Distance"]
distance=list(distance)

# %%
fig=plt.figure(figsize=(9,9))
plt.plot(rooms,distance,linestyle="-",marker="o",color="black",markerfacecolor="pink")
plt.xlabel("rooms")
plt.ylabel("distance")

plt.show()
